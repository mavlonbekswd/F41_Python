# %%
import pandas as pd

mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pd.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
mylesson = {
    'Moduls':["Machine Learning", "Database", "OOP", "Com Metodology", "Alghorithms"],
    'Grades': [84,78,73.2,81,82.2]
}

cheaking =pd.DataFrame(mylesson)
print(cheaking)
# Out:
#              Moduls  Grades
# 0  Machine Learning    84.0
# 1          Database    78.0
# 2               OOP    73.2
# 3    Com Metodology    81.0
# 4       Alghorithms    82.2

# %%
import pandas as pd
#A Pandas Series is like a column in a table.
a = [1, 7, 2]

myvar = pd.Series(a)

print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a, index = ["x", "y", "z"])

print(myvar)

myvar.rank()
# Out:
# x    1
# y    7
# z    2
# dtype: int64
# x    1.0
# y    3.0
# z    2.0
# dtype: float64

# %%
Lesson = ["Machine Learning", "Database", "OOP", "Com Metodology", "Alghorithms"]

chart = pd.Series(Lesson, index=["Dushanba:", "Seshanba:", "Chorshanba:", "Juma:", "Next Week:"])

print(chart)
"Dushanbe" in chart
# Out:
# Dushanba:      Machine Learning
# Seshanba:              Database
# Chorshanba:                 OOP
# Juma:            Com Metodology
# Next Week:          Alghorithms
# dtype: object
# False

# %%
Lesson = pd.Series(["Machine Learning", "Database", "OOP", "Com Metodology", "Alghorithms"],
                   index=["Dushanba:", "Seshanba:", "Chorshanba:", "Juma:", "Next Week:"])
print(Lesson)
# Out:
# Dushanba:      Machine Learning
# Seshanba:              Database
# Chorshanba:                 OOP
# Juma:            Com Metodology
# Next Week:          Alghorithms
# dtype: object

# %%
pd.isna(baholar)
# Out:
# False

# %%
"Machine Learning" in chart
# Out:
# False

# %%
baholar = {
    "Matematika": 85,
    "Fizika": 90,
    "Ingliz": 78,
    "Python": 95
}

testing = pd.Series(baholar)

print(testing)
# Out:
# Matematika    85
# Fizika        90
# Ingliz        78
# Python        95
# dtype: int64

# %%
chart.sort_values()

chart.sort_index(ascending=False)
# Out:
# ['Alghorithms', 'Com Metodology', 'Database', 'Machine Learning', 'OOP']

# %%
testing.rank()
# Out:
# Matematika    2.0
# Fizika        3.0
# Ingliz        1.0
# Python        4.0
# dtype: float64

# %%
df = pd.DataFrame({
    "name": ["Ali", "Vali", None, "Sardor"],
    "age": [20, None, 25, 30]
})

# %% [markdown]
# ###10. Value counts (oltin funksiya)

# %%
s = pd.Series(["a", "b", "a", "c", "a"])

print(s.value_counts())
# Out:
# a    3
# b    1
# c    1
# Name: count, dtype: int64

# %% [markdown]
# ###11. Map (real transformation)
# s = pd.Series(["M", "F", "M"])
#
# mapped = s.map({"M": "Male", "F": "Female"})
#
#  categorical data bilan ishlaganda juda kerak

# %%
s = pd.Series(["M", "F", "M"])

mapped = s.map({"M": "Male", "F": "Female"})

print(mapped)
# Out:
# 0      Male
# 1    Female
# 2      Male
# dtype: object
