# %% [markdown]
# #2D array indexing

# %%
import numpy as np

arr = np.array([
    [10, 20, 30],
    [40, 50, 60],
    [70, 80, 90]
])
print(arr)

# %% [markdown]
# #|       | col0 | col1 | col2 |
# #|-------|------|------|------|
# #| row0  | 10   | 20   | 30   |
# #| row1  | 40   | 50   | 60   |
# #| row2  | 70   | 80   | 90   |

# %% [markdown]
# ###Formula
#
# ####Eng muhim qoida:
#
# >birinchi son = row
# ###.
# >ikkinchi son = column

# %%
arr[row, column]
