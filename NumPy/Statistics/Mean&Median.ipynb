# %% [markdown]
# Online do‘kon bor.
#
# 20 ta customer buyurtma berdi.

# %%
import numpy as np

orders = np.array([
    120, 150, 180, 90, 110,
    130, 170, 140, 160, 125,
    135, 145, 155, 165, 175,
    115, 105, 185, 95, 5000
])

print("Mean:", np.mean(orders))
print("Median:", np.median(orders))
# Out:
# Mean: 382.5
# Median: 142.5
