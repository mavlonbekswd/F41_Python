# %% [markdown]
# Variance va STD deyarli aka-uka.
#
# Variance nima?
#
# STD: Tarqalish qanchalik katta?
#
# Variance: Tarqalishning kvadrati
#
# Variance = STD²

# %%
import numpy as np

arr = np.array([98,100,102])

print(np.std(arr))
print(np.var(arr))
# Out:
# 1.632993161855452
# 2.6666666666666665
