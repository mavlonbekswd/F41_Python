# %%
import numpy as np

arr = np.array([10, 20, 30, 40, 50])

print(arr > 25)
# Out:
# [False False  True  True  True]

# %%
10 > 25 → False
20 > 25 → False
30 > 25 → True
40 > 25 → True
50 > 25 → True

# %%
print(arr[arr>25])
# Out:
# [30 40 50]

# %%
arr = np.array([
    [10,20,30],
    [40,50,60]
])

print(arr[arr > 30])
# Out:
# [40 50 60]

# %%
arr = np.array([10, 15, 20, 25, 30, 35, 40])


newarray = (arr > 20) & (arr<40)

justnumber = (arr[newarray])
oddarray = (justnumber % 2 != 0)
finalarr =(justnumber[oddarray])

print(finalarr)
# Out:
# [25 35]

# %%
import numpy as np

arr = np.array([10, 15, 20, 25, 30, 35, 40])

result = arr[
    (arr > 20) &
    (arr < 40) &
    (arr % 2 != 0)
]

print(result)
# Out:
# [25 35]

# %%
import numpy as np

arr = np.array([10, 20, 30, 40, 50])

result = (arr > 25) & (arr <40)


print(result)
# Out:
# [False False  True False False]

# %% [markdown]
# OR condition
# arr[(arr < 20) | (arr > 40)]

# %%
matrix = np.array([
    [10, 20, 30],
    [40, 50, 60],
    [70, 80, 90]
])

comp = matrix[(matrix < 30) | (matrix > 80)]

print(comp)
# Out:
# [10 20 90]

# %%
#Condition bn value almashtirish
arr = np.array([10, 20, 30, 40])

result = arr[arr > 20] = 999

print(result)
# Out:
# 999
