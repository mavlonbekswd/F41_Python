# %%
import numpy as np

sales = np.array([
    [200, 150, 300],
    [220, 170, 310],
    [250, 160, 290],
    [210, 180, 305],
    [240, 175, 315],
    [260, 190, 330],
    [230, 185, 320]
])

print(sales)
# Out:
# [[200 150 300]
#  [220 170 310]
#  [250 160 290]
#  [210 180 305]
#  [240 175 315]
#  [260 190 330]
#  [230 185 320]]

# %% [markdown]
#           ProductA ProductB ProductC
# Day1        200      150      300
# Day2        220      170      310
# Day3        250      160      290
# ...

# %%
shape = sales.shape
print(shape)
# Out:
# (7, 3)

# %%
Product_Sales = np.sum(sales, axis=1) ##x va y o'qiga qarab tartiblaydi '
print(Product_Sales)

# %%
Daily_Sales = np.sum(sales, axis=0) ##x va y o'qiga qarab tartiblaydi '
print(Daily_Sales)

# %%
Max_reniev_by_product= np.max(sales, axis=0) #eng katta Product revenue lar
Max_reniev= np.max(sales)


print(Max_reniev_by_product)
print(Max_reniev)
# Out:
# [260 190 330]
# 330

# %%
discount = sales - 50

print(discount)
# Out:
# [[150 100 250]
#  [170 120 260]
#  [200 110 240]
#  [160 130 255]
#  [190 125 265]
#  [210 140 280]
#  [180 135 270]]

# %%
product_A = sales[:,0]

print(product_A)
# Out:
# [200 220 250 210 240 260 230]

# %%
percentage_test = product_A * 0.85

print(percentage_test)
# Out:
# [170.  187.  212.5 178.5 204.  221.  195.5]

# %%
percentage = np.percentile(product_A, 100)
print(percentage)
# Out:
# 260.0

# %%
day_3 = sales[3]

Avg = np.mean(day_3)

print(Avg)
# Out:
# 231.66666666666666

# %%
day = np.mean(sales, axis= 1)

argmaximum =np.argmax(day)
print(day)
print(argmaximum)
# Out:
# [216.66666667 233.33333333 233.33333333 231.66666667 243.33333333
#  260.         245.        ]
# 5

# %% [markdown]
# | Function      | Nima qaytaradi               |
# | ------------- | ---------------------------- |
# | `np.max()`    | eng katta qiymat             |
# | `np.argmax()` | eng katta qiymatning index’i |

# %%
testing1 = np.mean(sales[5,0])
print(testing1)
# Out:
# 260.0

# %%
day_avg = np.mean(sales, axis=1)

best_day_index = np.argmax(day_avg)

best_day_value = np.max(day_avg)

print(best_day_index + 1)
print(best_day_value)
# Out:
# 6
# 260.0
