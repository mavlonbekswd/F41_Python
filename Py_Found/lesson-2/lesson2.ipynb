# %%
greeting = "Hello, World!"
print(greeting)
# Out:
# Hello, World!

# %%
mynumber = -10
type(mynumber)
# Out:
# int

# %%
mynumber = 10
type(mynumber)
# Out:
# int

# %%
mynumber = 10
type(mynumber)
# Out:
# int
