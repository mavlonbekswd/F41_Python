# %%
from import module
# Out:
#   Cell In[6], line 1
#     import my_modules *
#                       ^
# SyntaxError: invalid syntax

# %%
import pandas

# %%
pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas

# %%
pip list
# Out:
# Package                 Version
# ----------------------- ------------
# aiofiles                24.1.0
# aiogram                 3.20.0.post0
# aiohappyeyeballs        2.6.1
# aiohttp                 3.11.18
# aiosignal               1.3.2
# annotated-types         0.7.0
# anyio                   4.9.0
# appnope                 0.1.4
# asttokens               3.0.0
# attrs                   25.3.0
# certifi                 2025.8.3
# comm                    0.2.2
# debugpy                 1.8.14
# decorator               5.2.1
# distro                  1.9.0
# executing               2.2.0
# frozenlist              1.6.0
# h11                     0.16.0
# httpcore                1.0.9
# httpx                   0.28.1
# idna                    3.10
# ipykernel               6.29.5
# ipython                 9.3.0
# ipython_pygments_lexers 1.1.1
# jedi                    0.19.2
# jiter                   0.9.0
# jupyter_client          8.6.3
# jupyter_core            5.8.1
# ...

# %%
python -m venv env
# Out:
#   Cell In[8], line 1
#     python -m venv env
#               ^
# SyntaxError: invalid syntax

# %%
pip install cowsay
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import threading

# %%
python3 -m venv env
# Out:
#   Cell In[11], line 1
#     python3 -m venv env
#                ^
# SyntaxError: invalid syntax

# %%
pip install cowsay
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
python test.py
# Out:
#   Cell In[1], line 1
#     python test.py
#            ^
# SyntaxError: invalid syntax

# %%
class Car:
    def __init__(self, brand, year, current_year):
        self.brand = brand
        self.year = year
        self.cur_yr = current_year
    def age_of_car(self):
        if self.cur_yr == 2026:
            return self.age_of_car()

car1 = Car("BMW", 2023, 2026)
print(car1.age_of_car())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 11
#       8             return self.age_of_car(self.cur_yr - self.year)
#      10 car1 = Car("BMW", 2023, 2026)
# ---> 11 print(car1.age_of_car())
#
# Cell In[9], line 8, in Car.age_of_car(self)
#       6 def age_of_car(self):
#       7     if self.cur_yr == 2026:
# ----> 8         return self.age_of_car(self.cur_yr - self.year)
#
# TypeError: Car.age_of_car() takes 1 positional argument but 2 were given
