# %%
name = input("Enter your name: ")
hobby = input("Enter your hobby: ")
(f"Hi {name}, that’s awesome! You like {hobby}.")

# %%
name = input("Enter your name: ")
hobby = input("Enter your hobby: ")
print(f"Hi {name}, that’s awesome! You like {hobby}.")
